# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
from os import scandir, getcwd
import cv2
import numpy as np
import pandas as pd

def ls(ruta):
    return [arch.name for arch in scandir(ruta) if arch.is_file()]

width = 28
height = 28

# %%
#
from glob import glob
from google.colab.patches import cv2_imshow
#cv2_imshow(img)
test_mild_path = glob("/content/drive/MyDrive/Alzhimer/test/Affected /MildDemented*/*")
test_normal_path = glob("/content/drive/MyDrive/Alzhimer/test/Normal/NonDemented*/*")
test_moderate_path = glob("/content/drive/MyDrive/Alzhimer/test/Affected /ModerateDemented*/*")
test_verymild_path = glob("/content/drive/MyDrive/Alzhimer/test/Affected /VeryMildDemented*/*")
list_mild_test = []
list_normal_test = []
list_moderate_test = []
list_verymild_test = []

# %%
from glob import glob
from google.colab.patches import cv2_imshow
#cv2_imshow(img)
def read_images(test_covid_path):
  lst_images = []
  for i in range(len(test_covid_path)):
    img = cv2.imread(test_covid_path[i],0)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img= cv2.resize(img, (28, 28))
    #cv2_imshow(img)
    lst_images.append(img)
  return lst_images

# %%
def read_images(test_covid_path):
  list_covid_test = []
  for image in range(len(test_covid_path)):

#for image in files_0:
    img = cv2.imread(test_covid_path[image], 0)
    dim = (width, height)
    imagen_entrada = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    imagen_entrada = imagen_entrada.flatten()
    imagen_entrada = np.insert(imagen_entrada,len(imagen_entrada),0)
    list_covid_test.append(imagen_entrada)

# %%
#cv2_imshow(img)
def read_images(test_normal_path):
  lst_images = []
  for i in range(len(test_normal_path)):
    img = cv2.imread(test_normal_path[i],0)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img= cv2.resize(img, (28, 28))
    #cv2_imshow(img)
    lst_images.append(img)
  return lst_images

# %%
len(test_mild_path), len(test_normal_path), len(test_moderate_path), len(test_verymild_path)

# %%
# verymild=1, mild=2, moderate=3, normal=0
files_0 = test_verymild_path

for i in range(len(test_verymild_path)):
	img = cv2.imread(test_verymild_path[i], 0)
	dim = (width, height)
	imagen_entrada = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
	imagen_entrada = imagen_entrada.flatten()
	imagen_entrada = np.insert(imagen_entrada,len(imagen_entrada),1)
	list_verymild_test.append(imagen_entrada)

df_verymild_test = pd.DataFrame(data=list_verymild_test, index=[i for i in range(len(list_verymild_test))])

# %%
print(df_verymild_test)

# %%
print(list_verymild_test)

# %%
# very mild=1, mild=2, moderate=3, normal=0
files_0 = test_mild_path

for i in range(len(test_mild_path)):
	img = cv2.imread(test_mild_path[i], 0)
	dim = (width, height)
	imagen_entrada = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
	imagen_entrada = imagen_entrada.flatten()
	imagen_entrada = np.insert(imagen_entrada,len(imagen_entrada),2)
	list_mild_test.append(imagen_entrada)

df_mild_test = pd.DataFrame(data=list_mild_test, index=[i for i in range(len(list_mild_test))])

# %%
print(list_mild_test)

# %%
# very mild=1, mild=2, moderate=3, normal=0
files_0 = test_moderate_path

for i in range(len(test_moderate_path)):
	img = cv2.imread(test_moderate_path[i], 0)
	dim = (width, height)
	imagen_entrada = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
	imagen_entrada = imagen_entrada.flatten()
	imagen_entrada = np.insert(imagen_entrada,len(imagen_entrada),3)
	list_moderate_test.append(imagen_entrada)

df_moderate_test = pd.DataFrame(data=list_moderate_test, index=[i for i in range(len(list_moderate_test))])

# %%
print(list_moderate_test)

# %%
files_1 = test_normal_path

for i in range(len(test_normal_path)):
	img = cv2.imread(test_normal_path[i], 0)
	dim = (width, height)
	imagen_entrada = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
	imagen_entrada = imagen_entrada.flatten()
	imagen_entrada = np.insert(imagen_entrada,len(imagen_entrada),0)
	list_normal_test.append(imagen_entrada)

df_normal_test = pd.DataFrame(data=list_normal_test, index=[i for i in range(len(list_normal_test))])
print(df_normal_test)

# %%
dframes_test = [df_verymild_test, df_mild_test, df_moderate_test, df_normal_test]
df_test = pd.concat(dframes_test)
print(df_test)

# %%
df_test.to_csv('/content/drive/MyDrive/Alzhimer/test/test.csv',header=None,index=False)

# %%
# Import NumPy
import numpy as np
# Load the original CSV file
test_file = np.genfromtxt("/content/drive/MyDrive/Alzhimer/test/test.csv", delimiter = ',',)
print(test_file)

# %%
# Save the CVS file to NPY file
np.save("/content/drive/MyDrive/Alzhimer/test.np", test_file)

# %%
# for train dataset
from glob import glob
from google.colab.patches import cv2_imshow
#cv2_imshow(img)
train_mild_path = glob("/content/drive/MyDrive/Alzhimer/train/Affected /MildDemented*/*")
train_normal_path = glob("/content/drive/MyDrive/Alzhimer/train/Normal/NonDemented*/*")
train_moderate_path = glob("/content/drive/MyDrive/Alzhimer/train/Affected /ModerateDemented*/*")
train_verymild_path = glob("/content/drive/MyDrive/Alzhimer/train/Affected /VeryMildDemented*/*")
list_mild_train= []
list_normal_train = []
list_moderate_train = []
list_verymild_train = []

# %%
len(train_mild_path), len(train_normal_path), len(train_moderate_path), len(train_verymild_path)

# %%
# very mild=1, mild=2, moderate=3, normal=0

files_0 = train_verymild_path

for i in range(len(train_verymild_path)):
	img = cv2.imread(train_verymild_path[i], 0)
	dim = (width, height)
	imagen_entrada = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
	imagen_entrada = imagen_entrada.flatten()
	imagen_entrada = np.insert(imagen_entrada,len(imagen_entrada),1)
	list_verymild_train.append(imagen_entrada)

# %%
df_verymild_train = pd.DataFrame(data=list_verymild_train, index=[i for i in range(len(list_verymild_train))])
print(df_verymild_train)

# %%
print(list_verymild_train)

# %%
files_0 = train_mild_path

for i in range(len(train_mild_path)):
	img = cv2.imread(train_mild_path[i], 0)
	dim = (width, height)
	imagen_entrada = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
	imagen_entrada = imagen_entrada.flatten()
	imagen_entrada = np.insert(imagen_entrada,len(imagen_entrada),2)
	list_mild_train.append(imagen_entrada)

df_mild_train = pd.DataFrame(data=list_mild_train, index=[i for i in range(len(list_mild_train))])

# %%
df_mild_train = pd.DataFrame(data=list_mild_train, index=[i for i in range(len(list_mild_train))])
print(df_mild_train)

# %%
print(list_mild_train)

# %%
files_0 = train_moderate_path

for i in range(len(train_moderate_path)):
	img = cv2.imread(train_moderate_path[i], 0)
	dim = (width, height)
	imagen_entrada = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
	imagen_entrada = imagen_entrada.flatten()
	imagen_entrada = np.insert(imagen_entrada,len(imagen_entrada),3)
	list_moderate_train.append(imagen_entrada)

df_moderate_train = pd.DataFrame(data=list_moderate_train, index=[i for i in range(len(list_moderate_train))])

# %%
df_moderate_train = pd.DataFrame(data=list_moderate_train, index=[i for i in range(len(list_moderate_train))])
print(df_moderate_train)

# %%
print(list_moderate_train)

# %%
files_0 = train_normal_path

for i in range(len(train_normal_path)):
	img = cv2.imread(train_normal_path[i], 0)
	dim = (width, height)
	imagen_entrada = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
	imagen_entrada = imagen_entrada.flatten()
	imagen_entrada = np.insert(imagen_entrada,len(imagen_entrada),0)
	list_normal_train.append(imagen_entrada)

df_normal_train = pd.DataFrame(data=list_normal_train, index=[i for i in range(len(list_normal_train))])

# %%
df_normal_train = pd.DataFrame(data=list_normal_train, index=[i for i in range(len(list_normal_train))])
print(df_normal_train)

# %%
print(list_normal_train)

# %%
dframes_train = [df_verymild_train, df_mild_train, df_moderate_train, df_normal_train]
df_train = pd.concat(dframes_train)
print(df_train)

# %%
df_train.to_csv('/content/drive/MyDrive/Alzhimer/train/train.csv',header=None,index=False)

# %%
# Import NumPy
import numpy as np
# Load the original CSV file
train_file = np.genfromtxt("/content/drive/MyDrive/Alzhimer/train/train.csv", delimiter = ',', )
print(train_file)

# %%
# Save the CVS file to NPY file
np.save("/content/drive/MyDrive/Alzhimer/train/train_npy.npy", train_file)

# %%
#quantum classifier

# !pip install pennylane --upgrade

from IPython.display import clear_output
clear_output(wait=False)

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers


#import tensorflow as tf
#from tensorflow import keras

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# %%
train_data = np.array(pd.read_csv('/content/drive/MyDrive/Alzhimer/train/train.csv'))
test_data = np.array(pd.read_csv('/content/drive/MyDrive/Alzhimer/test/test.csv'))

# %%
train_data.shape, test_data.shape

# %%
train_len = len(train_data)
test_len = len(test_data)
train_len, test_len

# %%
x_train = train_data[:, 0:784]
y_train = train_data[:, 784]

x_test = test_data[:, 0:784]
y_test = test_data[:, 784]

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
 x_train.shape, x_test.shape

# %%
x_train = x_train.reshape(5120,28,28)
x_test = x_test.reshape(1481,28,28)

# %%
# !nvidia-smi

# %%
# !pip install tensorflow

# %%
import numpy as np
import tensorflow as tf
x_train = np.array(x_train[..., tf.newaxis])
x_test = np.array(x_test[..., tf.newaxis])
x_train.shape, x_test.shape

# %%
n_layers_quanv1 = 1

dev_1 = qml.device("default.qubit", wires=4)
# Random circuit parameters
quanv_1_params = np.random.uniform(high=2 * np.pi, size=(n_layers_quanv1, 4))

@qml.qnode(dev_1)
def circuit_1(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(quanv_1_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv_1(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit_1(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %%
x_train_quanv_1 = []
x_test_quanv_1 = []


print("Quanvoltional(layer-1) preprocessing of train images:")
for idx, img in enumerate(x_train):
    if((idx+1)%10==0):
        print("Train Image => {}/{}        ".format(idx + 1, train_len))
    x_train_quanv_1.append(quanv_1(img))


x_train_quanv_1 = np.array(x_train_quanv_1)



print("\nQuanvolutional(layer-1) preprocessing of test images:")
for idx, img in enumerate(x_test):
    if((idx+1)%10==0):
        print("Test Image => {}/{}        ".format(idx + 1, test_len))
    x_test_quanv_1.append(quanv_1(img))


x_test_quanv_1 = np.array(x_test_quanv_1)

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(x_train[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(x_train_quanv_1[k, :, :, c]*256, cmap="gray")

plt.tight_layout()
plt.show()

# %%
x_train_quanv_1.shape, x_test_quanv_1.shape

# %%
 #Quanvolution Layer -2

n_layers_quanv2 = 1

dev_2 = qml.device("default.qubit", wires=4)
# Random circuit parameters
quanv_2_params = np.random.uniform(high=2 * np.pi, size=(n_layers_quanv2, 4))

@qml.qnode(dev_2)
def circuit_2(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(quanv_2_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv_2(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((7, 7, 16))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 14, 2):
        for k in range(0, 14, 2):
            for l in range(4):
                # Process a squared 2x2 region of the image with a quantum circuit
                q_results = circuit_2(
                    [
                        image[j, k, l],
                        image[j, k + 1, l],
                        image[j + 1, k, l],
                        image[j + 1, k + 1, l]
                    ]
                )
                # Assign expectation values to different channels of the output pixel (j/2, k/2)
                for c in range(4):
                    out[j // 2, k // 2, (l*4)+c] = q_results[c]
    return out

# %%
x_train_quanv_2 = []
x_test_quanv_2 = []


print("Quanvoltional(layer-2) preprocessing of train images:")
for idx, img in enumerate(x_train_quanv_1):
    if((idx+1)%10==0):
        print("Train Image => {}/{}        ".format(idx + 1, train_len))
    x_train_quanv_2.append(quanv_2(img))

x_train_quanv_2 = np.array(x_train_quanv_2)



print("\nQuanvolutional(layer-2) preprocessing of test images:")
for idx, img in enumerate(x_test_quanv_1):
    if((idx+1)%5==0):
        print("Test Image => {}/{}        ".format(idx + 1, test_len))
    x_test_quanv_2.append(quanv_2(img))

x_test_quanv_2 = np.array(x_test_quanv_2)

# %%
n_samples = 4
n_channels = 16
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 40))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(x_train[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(x_train_quanv_2[k, :, :, c]*256, cmap="gray")

plt.tight_layout()
plt.show()

# %%
x_train_quanv_2.shape, x_test_quanv_2.shape

# %%
#Quanvolution Layer -3
n_layers_quanv3 = 1

dev_3 = qml.device("default.qubit", wires=4)
# Random circuit parameters
quanv_3_params = np.random.uniform(high=2 * np.pi, size=(n_layers_quanv3, 4))

@qml.qnode(dev_3)
def circuit_3(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(quanv_3_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv_3(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((3, 3, 64))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 6, 2):
        for k in range(0, 6, 2):
            for l in range(16):
                # Process a squared 2x2 region of the image with a quantum circuit
                q_results = circuit_3(
                    [
                        image[j, k, l]*image[j+1, k+1, l],
                        image[j, k + 2, l]*image[j+1, k+1, l],
                        image[j + 2, k, l]*image[j+1, k+1, l],
                        image[j + 2, k + 2, l]*image[j+1, k+1, l]
                    ]
                )
                # Assign expectation values to different channels of the output pixel (j/2, k/2)
                for c in range(4):
                    out[(j+2) // 3, (k+2) // 3, (l*4)+c] = q_results[c]
    return out

# %%
x_train_quanv_3 = []
x_test_quanv_3 = []


print("Quanvoltional(layer-3) preprocessing of train images:")
for idx, img in enumerate(x_train_quanv_2):
    if((idx+1)%10==0):
        print("Train Image => {}/{}        ".format(idx + 1, train_len))
    x_train_quanv_3.append(quanv_3(img))

x_train_quanv_3 = np.array(x_train_quanv_3)



print("\nQuanvolutional(layer-3) preprocessing of test images:")
for idx, img in enumerate(x_test_quanv_2):
    if((idx+1)%5==0):
        print("Test Image => {}/{}        ".format(idx + 1, test_len))
    x_test_quanv_3.append(quanv_3(img))

x_test_quanv_3 = np.array(x_test_quanv_3)

# %%
n_samples = 4
n_channels = 20
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 50))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(x_train[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(x_train_quanv_3[k, :, :, c]*256, cmap="gray")

plt.tight_layout()
plt.show()

# %%
x_train_quanv_3.shape, x_test_quanv_3.shape

# %%
n_layers_quanv4 = 1

dev_4 = qml.device("default.qubit", wires=4)
# Random circuit parameters
quanv_4_params = np.random.uniform(high=2 * np.pi, size=(n_layers_quanv4, 4))

@qml.qnode(dev_4)
def circuit_4(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(quanv_4_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv_4(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((1, 1, 256))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0,2,2):
        for k in range(0,2,2):
            for l in range(64):
                # Process a squared 2x2 region of the image with a quantum circuit
                q_results = circuit_4(
                    [
                        image[j, k, l]*image[j+1, k+1, l],
                        image[j, k + 2, l]*image[j+1, k+1, l],
                        image[j + 2, k, l]*image[j+1, k+1, l],
                        image[j + 2, k + 2, l]*image[j+1, k+1, l]
                    ]
                )
                # Assign expectation values to different channels of the output pixel (j/2, k/2)
                for c in range(4):
                    out[(j+2) // 3, (k+2) // 3, (l*4)+c] = q_results[c]
    return out

# %%
x_train_quanv_4 = []
x_test_quanv_4 = []


print("Quanvoltional(layer-4) preprocessing of train images:")
for idx, img in enumerate(x_train_quanv_3):
    if((idx+1)%10==0):
        print("Train Image => {}/{}        ".format(idx + 1, train_len))
    x_train_quanv_4.append(quanv_4(img))

x_train_quanv_4 = np.array(x_train_quanv_4)



print("\nQuanvolutional(layer-4) preprocessing of test images:")
for idx, img in enumerate(x_test_quanv_3):
    if((idx+1)%5==0):
        print("Test Image => {}/{}        ".format(idx + 1, test_len))
    x_test_quanv_4.append(quanv_4(img))

x_test_quanv_4 = np.array(x_test_quanv_4)

# %%
# n_samples = 4
# n_channels = 20
#fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 50))
#for k in range(n_samples):
   #  axes[0, 0].set_ylabel("Input")
   #  if k != 0:         axes[0, k].yaxis.set_visible(False)
   #  axes[0, k].imshow(x_train[k, :, :, 0], cmap="gray")

     # Plot all output channels
  #   for c in range(n_channels):
      #   axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
      #   if k != 0:
      #       axes[c, k].yaxis.set_visible(False)
   #      axes[c + 1, k].imshow(x_train_quanv_4[k, :, :, c]*256, cmap="gray")

# plt.tight_layout()
 #plt.show()

# %%
x_train_quanv_4.shape, x_test_quanv_4.shape

# %%
x_train_final = x_train_quanv_4.reshape(5120, 256)
x_test_final = x_test_quanv_4.reshape(1481, 256)

# %%
x_train_final.shape, x_test_final.shape

# %%
np.save("/content/drive/MyDrive/Alzhimer/train/x_train_final.npy", x_train_final)
np.save("/content/drive/MyDrive/Alzhimer/train/y_train.npy", y_train)

np.save("/content/drive/MyDrive/Alzhimer/test/x_test_final.npy", x_test_final)
np.save("/content/drive/MyDrive/Alzhimer/test/y_test.npy", y_test)

# %%
#quantum classifier_1
#https://github.com/QTechnocrats/covid19-detection-chest-xray-dataset/blob/main/quantum_classifier_1.ipynb

# %%
# !pip install pennylane --upgrade

from IPython.display import clear_output
clear_output(wait=False)

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers


#import tensorflow as tf
#from tensorflow import keras

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# %%
 x_train_final = np.load("/content/drive/MyDrive/Alzhimer/train/x_train_final.npy")
y_train = np.load("/content/drive/MyDrive/Alzhimer/train/y_train.npy")
x_test_final = np.load("/content/drive/MyDrive/Alzhimer/test/x_test_final.npy")
y_test = np.load("/content/drive/MyDrive/Alzhimer/test/y_test.npy")

# %%
 x_train_final.shape, y_train.shape, x_test_final.shape, y_test.shape

# %%
X = np.concatenate((x_train_final, x_test_final))
Y = np.concatenate((y_train, y_test))
print(X.shape)

# %%
print(y_train)

# %%
print(y_test)

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False,max_iter=150000).fit(X, Y)
model = SelectFromModel(lsvc, prefit=True)
X = model.transform(X)
print(X.shape)

# %%
x_train_final = (X[:5120])
x_test_final = (X[5120:])

# %%
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

colours = ["#ec6f86", "#4573e7", "#ad61ed", "#d62424"]


def plot_points(x_train, y_train, x_test, y_test):
    c_train = []
    c_test = []

    # Convert y_train and y_test to numpy arrays and extract class labels
    y_train = y_train.numpy()  # Assuming y_train is a PyTorch tensor
    y_test = y_test.numpy()   # Assuming y_test is a PyTorch tensor

    for y in y_train:
        c_train.append(colours[y])

    for y in y_test:
        c_test.append(colours[y])

    plt.scatter(x_train[:, 0], x_train[:, 1], c=c_train)
    plt.scatter(x_test[:, 0], x_test[:, 1], c=c_test, marker="x")

    plt.xlabel("Feature 1", fontsize=16)
    plt.ylabel("Feature 2", fontsize=16)

    ax = plt.gca()
    ax.set_aspect(1)

    c_transparent = "#00000000"

    custom_lines = [
        Patch(facecolor=colours[0], edgecolor=c_transparent, label="Class 0"),
        Patch(facecolor=colours[1], edgecolor=c_transparent, label="Class 1"),
        Patch(facecolor=colours[2], edgecolor=c_transparent, label="Class 2"),
        Patch(facecolor=colours[3], edgecolor=c_transparent, label="Class 3"),
        Line2D([0], [0], marker="o", color=c_transparent, label="Train",
               markerfacecolor="black", markersize=10),
        Line2D([0], [0], marker="x", color=c_transparent, label="Test",
               markerfacecolor="black", markersize=10),
    ]

    ax.legend(handles=custom_lines, bbox_to_anchor=(1.0, 0.75))


plot_points(x_train_final, y_train, x_test_final, y_test)

# %%
#Required functions for classifier model-1
def get_angles(x):

    beta0 = 2 * np.arcsin(np.sqrt(x[1] ** 2) / np.sqrt(x[0] ** 2 + x[1] ** 2 + 1e-12))
    beta1 = -2 * np.arcsin(np.sqrt(x[1] ** 2) / np.sqrt(x[2] ** 2 + x[1] ** 2 + 1e-12))
    beta2 = 2 * np.arcsin(np.sqrt(x[2] ** 2 + x[1] ** 2)/np.sqrt(x[0] ** 2 + x[1] ** 2 + x[2] ** 2 ))

    return np.array([beta2, -beta1 / 2, beta1 / 2, -beta0 / 2, beta0 / 2])

# %%
def statepreparation_1(a):

        qml.Hadamard(wires=0)
        qml.Hadamard(wires=1)

        qml.RZ(a[0], wires=0)
        qml.RZ(a[1], wires=1)
        qml.CNOT(wires=[0,1])
        qml.RZ(a[0]*a[1], wires=1)
        qml.CNOT(wires=[0,1])

        qml.Hadamard(wires=0)
        qml.Hadamard(wires=1)

        qml.RZ(a[1], wires=0)
        qml.RZ(a[2], wires=1)
        qml.CNOT(wires=[0,1])
        qml.RZ(a[1]*a[2], wires=1)
        qml.CNOT(wires=[0,1])



        qml.RY(a[0], wires=0)

        qml.CNOT(wires=[0, 1])
        qml.RY(a[1], wires=1)
        qml.CNOT(wires=[0, 1])
        qml.RY(a[2], wires=1)

        for i in range(3,10):
            qml.PauliX(wires=0)
            qml.CNOT(wires=[0, 1])
            qml.RY(a[i], wires=1)
            qml.CNOT(wires=[0, 1])
            qml.RY(a[i+1], wires=1)
            qml.PauliX(wires=0)

# %%
def layer_1(W):
    qml.Rot(W[0, 0], W[0, 1], W[0, 2], wires=0)
    qml.Rot(W[1, 0], W[1, 1], W[1, 2], wires=1)
    # qml.Rot(W[2, 0], W[2, 1], W[2, 2], wires=2)

    qml.CNOT(wires=[0, 1])
    # qml.CNOT(wires=[0, 2])
    # qml.CNOT(wires=[1, 2])

# %%
dev_1 = qml.device("default.qubit", wires=2)
@qml.qnode(dev_1)
def circuit_1(weights, x=None):
    # Feature mapping
    # angle = get_angles(x)
    statepreparation_1(x)
    # variational classifier
    for w in weights:
        layer_1(w)

    return qml.expval(qml.PauliZ(1))

# %%
def classifier_training_1(params, x=None, y=None):
    weights = params[0]
    bias = params[1]

    out_probs = circuit_1(weights, x=x) + bias
    return (out_probs-y)**2

# %%
def classifier_prediction_1(params, x=None):
    weights = params[0]
    bias = params[1]

    out_probs = circuit_1(weights, x=x) + bias


    if(out_probs>0):
        return 1
    else:
        return -1

# %%
def circuit_output_test(params, x=None):
    weights = params[0]
    bias = params[1]

    out_probs = circuit(weights, x=x) + bias

    return out_probs

# %%
def cost_1(params, X, Y):

    y_pred = np.array([classifier_training_1(params, x=X[i], y=Y[i]) for i in range(len(Y))])

    cost = np.sum(y_pred) / len(Y)
    return cost

# %%
def accuracy_1(params, x_train, y_train, iter):

    y_pred_train = np.array([classifier_prediction_1(params, x=x) for x in x_train])
    acc_train = np.sum(y_pred_train==y_train) / len(y_train)

    print("Iter=> {}   train_cost=> {}   train_acc=> {} ".format(iter+1, cost_1(params, x_train, y_train), acc_train))

    return acc_train

# %%
#Data for model-1
#0->covid, 1->Normal, 2->Penumonia

# %%
x_train_1 = np.copy(x_train_final)
y_train_1 = []

for i in range(len(y_train)):
    if(y_train[i]==1 or y_train[i]==2 or y_train[i]==3):  ##Covid or pneumonia
        y_train_1.append(-1)
    elif(y_train[i]==0):  ##normal person
        y_train_1.append(1)

y_train_1 = np.array(y_train_1)

# %%
#Binary Classifier Model-1
params_1 = (0.01 * np.random.randn(2, 2, 3), 0.0)
params_1

# %%
iters = 20
optimizer_1 = qml.AdagradOptimizer(stepsize=0.5)

cost_list_1 = []
train_acc_list_1 = []

for iter in range(iters):
    params_1 = optimizer_1.step(lambda v: cost_1(v, x_train_1, y_train_1), params_1)

    cost_list_1.append(cost_1(params_1, x_train_1, y_train_1))
    train_acc_list_1.append(accuracy_1(params_1, x_train_1, y_train_1, iter))

# %%
iters = 20
optimizer_1 = qml.NesterovMomentumOptimizer(stepsize=0.5)

cost_list_1 = []
train_acc_list_1 = []

for iter in range(iters):
    params_1 = optimizer_1.step(lambda v: cost_1(v, x_train_1, y_train_1), params_1)

    cost_list_1.append(cost_1(params_1, x_train_1, y_train_1))
    train_acc_list_1.append(accuracy_1(params_1, x_train_1, y_train_1, iter))

# %%
#Cost Plot of Model-1
plt.plot(cost_list_1)

# %%
#Training Accuracy Plot of Model-1
plt.plot(train_acc_list_1)

# %%
#prediction
y_pred = []

for i in range(len(x_test_final)):
    tmp = classifier_prediction_1(params_1, x=x_test_final[i])
    if (tmp == 1):  ## Normal person
        y_pred.append(1)
    else:   ## Covid or Pneumonia
        tmp = classifier_prediction_2(params_2, x=x_test_final[i])
        if(tmp == 1):  ## covid
            y_pred.append(0)
        elif(tmp == -1): ## Pneumonia
            y_pred.append(2)

y_pred = np.array(y_pred)

# %%
print("Final_Test_Accuracy => ", np.sum(y_pred==y_test)/len(y_test))

# %%
# !pip install pennylane --upgrade

from IPython.display import clear_output
clear_output(wait=False)

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers

import tensorflow as tf
from tensorflow import keras

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE

# %%
x_train_final = np.load("/content/drive/MyDrive/Alzhimer/train/x_train_final.npy")
y_train = np.load("/content/drive/MyDrive/Alzhimer/train/y_train.npy")

x_test_final = np.load("/content/drive/MyDrive/Alzhimer/test/x_test_final.npy")
y_test = np.load("/content/drive/MyDrive/Alzhimer/test/y_test.npy")


x_train_final.shape, y_train.shape, x_test_final.shape, y_test.shape

# %%
def statepreparation_1(a):


    qml.Hadamard(wires=0)
    qml.Hadamard(wires=1)

    qml.RZ(a[0], wires=0)
    qml.RZ(a[1], wires=1)
    qml.CNOT(wires=[0,1])
    qml.RZ(a[0]*a[1], wires=1)
    qml.CNOT(wires=[0,1])

    qml.Hadamard(wires=0)
    qml.Hadamard(wires=1)

    qml.RZ(a[2], wires=0)
    qml.RZ(a[3], wires=1)
    qml.CNOT(wires=[0,1])
    qml.RZ(a[2]*a[3], wires=1)
    qml.CNOT(wires=[0,1])

# %%
def layer_1(W):
    qml.Rot(W[0, 0], W[0, 1], W[0, 2], wires=0)
    qml.Rot(W[1, 0], W[1, 1], W[1, 2], wires=1)
    # qml.Rot(W[2, 0], W[2, 1], W[2, 2], wires=2)

    qml.CNOT(wires=[0, 1])
    # qml.CNOT(wires=[0, 2])
    # qml.CNOT(wires=[1, 2])

# %%
dev_1 = qml.device("default.qubit", wires=2)
@qml.qnode(dev_1)
def circuit_1(weights, x=None):

    # Feature mapping
    statepreparation_1(x)
    # variational classifier
    for w in weights:
        layer_1(w)

    return qml.expval(qml.PauliZ(1))

# %%
def classifier_training_1(params, x=None, y=None):
    weights = params[0]
    bias = params[1]

    out_probs = circuit_1(weights, x=x) + bias
    return (out_probs-y)**2

# %%
def classifier_prediction_1(params, x=None):
    weights = params[0]
    bias = params[1]

    out_probs = circuit_1(weights, x=x) + bias


    if(out_probs>0):
        return 1
    else:
        return -1

# %%
def circuit_output_test(params, x=None):
    weights = params[0]
    bias = params[1]

    out_probs = circuit(weights, x=x) + bias

    return out_probs

# %%
 def cost_1(params, X, Y):

    y_pred = np.array([classifier_training_1(params, x=X[i], y=Y[i]) for i in range(len(Y))])

    cost = np.sum(y_pred) / len(Y)
    return cost

# %%
def accuracy_1(params, x_train, y_train, iter):

    y_pred_train = np.array([classifier_prediction_1(params, x=x) for x in x_train])
    acc_train = np.sum(y_pred_train==y_train) / len(y_train)

    print("Iter=> {}   train_cost=> {}   train_acc=> {} ".format(iter+1, cost_1(params, x_train, y_train), acc_train))

    return acc_train

# %%
def statepreparation_2(a):


    qml.Hadamard(wires=0)
    qml.Hadamard(wires=1)

    qml.RZ(a[0], wires=0)
    qml.RZ(a[1], wires=1)
    qml.CNOT(wires=[0,1])
    qml.RZ(a[0]*a[1], wires=1)
    qml.CNOT(wires=[0,1])

    qml.Hadamard(wires=0)
    qml.Hadamard(wires=1)

    qml.RZ(a[2], wires=0)
    qml.RZ(a[3], wires=1)
    qml.CNOT(wires=[0,1])
    qml.RZ(a[2]*a[3], wires=1)
    qml.CNOT(wires=[0,1])

# %%
def layer_2(W):
    qml.Rot(W[0, 0], W[0, 1], W[0, 2], wires=0)
    qml.Rot(W[1, 0], W[1, 1], W[1, 2], wires=1)
    # qml.Rot(W[2, 0], W[2, 1], W[2, 2], wires=2)

    qml.CNOT(wires=[0, 1])
    # qml.CNOT(wires=[0, 2])
    # qml.CNOT(wires=[1, 2])

# %%
dev_2 = qml.device("default.qubit", wires=2)
@qml.qnode(dev_2)
def circuit_2(weights, x=None):

    # Feature mapping
    statepreparation_2(x)

    # variational classifier
    for w in weights:
        layer_2(w)

    return qml.expval(qml.PauliZ(1))

# %%
def classifier_training_2(params, x=None, y=None):
    weights = params[0]
    bias = params[1]

    out_probs = circuit_2(weights, x=x) + bias
    return (out_probs-y)**2

# %%
def classifier_prediction_2(params, x=None):
    weights = params[0]
    bias = params[1]

    out_probs = circuit_2(weights, x=x) + bias


    if(out_probs>0):
        return 1
    else:
        return -1

# %%
def cost_2(params, X, Y):

    y_pred = np.array([classifier_training_2(params, x=X[i], y=Y[i]) for i in range(len(Y))])

    cost = np.sum(y_pred) / len(Y)
    return cost

# %%
def accuracy_2(params, x_train, y_train, iter):

    y_pred_train = np.array([classifier_prediction_2(params, x=x) for x in x_train])
    acc_train = np.sum(y_pred_train==y_train) / len(y_train)

    print("Iter=> {}   train_cost=> {}   train_acc=> {} ".format(iter+1, cost_2(params, x_train, y_train), acc_train))

    return acc_train
